# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinmuhtiga/Algoritma-pemrograman/blob/main/learn%201%20-python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
materi pertama tentang pemahaman penggunaan python

# %%
a=2
b=3
c=a+b
print (c)
# Out:
# 5
